# %%
import pandas as pd
import numpy as np
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-e97ac9fe-4765-4f93-ab76-9a18f30045d0" name="files[]" multiple disabled />
#      <output id="result-e97ac9fe-4765-4f93-ab76-9a18f30045d0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving outb.csv to outb.csv

# %%
main_df = pd.read_csv("outb.csv")
main_df
# Out:
#        Year  ...                                 Species
# 0      1998  ...                                     NaN
# 1      1998  ...                                     NaN
# 2      1998  ...                                     NaN
# 3      1998  ...                         Scombroid toxin
# 4      1998  ...                     Salmonella enterica
# 5      1998  ...                         Shigella boydii
# 6      1998  ...                                     NaN
# 7      1998  ...                     Salmonella enterica
# 8      1998  ...                                   Virus
# 9      1998  ...                                   Virus
# 10     1998  ...                                   Virus
# 11     1998  ...                                   Virus
# 12     1998  ...                                   Virus
# 13     1998  ...                                     NaN
# 14     1998  ...                                     NaN
# ...

# %%
month_df=main_df.groupby('Month')

# %%
month_df.get_group('January')
# Out:
#        Year  ...                  Species
# 0      1998  ...                      NaN
# 1      1998  ...                      NaN
# 2      1998  ...                      NaN
# 3      1998  ...          Scombroid toxin
# 4      1998  ...      Salmonella enterica
# 5      1998  ...          Shigella boydii
# 6      1998  ...                      NaN
# 7      1998  ...      Salmonella enterica
# 8      1998  ...                    Virus
# 9      1998  ...                    Virus
# 10     1998  ...                    Virus
# 11     1998  ...                    Virus
# 12     1998  ...                    Virus
# 13     1998  ...                      NaN
# 14     1998  ...                      NaN
# 15     1998  ...  Clostridium perfringens
# 16     1998  ...    Norovirus genogroup I
# 17     1998  ...    Staphylococcus aureus
# 18     1998  ...          Bacillus cereus
# 19     1998  ...          Scombroid toxin
# 20     1998  ...    Campylobacter unknown
# ...

# %%
jan_df=month_df.get_group('January')
jan_df
# Out:
#        Year  ...                  Species
# 0      1998  ...                      NaN
# 1      1998  ...                      NaN
# 2      1998  ...                      NaN
# 3      1998  ...          Scombroid toxin
# 4      1998  ...      Salmonella enterica
# 5      1998  ...          Shigella boydii
# 6      1998  ...                      NaN
# 7      1998  ...      Salmonella enterica
# 8      1998  ...                    Virus
# 9      1998  ...                    Virus
# 10     1998  ...                    Virus
# 11     1998  ...                    Virus
# 12     1998  ...                    Virus
# 13     1998  ...                      NaN
# 14     1998  ...                      NaN
# 15     1998  ...  Clostridium perfringens
# 16     1998  ...    Norovirus genogroup I
# 17     1998  ...    Staphylococcus aureus
# 18     1998  ...          Bacillus cereus
# 19     1998  ...          Scombroid toxin
# 20     1998  ...    Campylobacter unknown
# ...

# %%
feb_df=month_df.get_group('February')
mar_df=month_df.get_group('March')
apr_df=month_df.get_group('April')
may_df=month_df.get_group('May')
jun_df=month_df.get_group('June')
jul_df=month_df.get_group('July')
aug_df=month_df.get_group('August')
sep_df=month_df.get_group('September')
oct_df=month_df.get_group('October')
nov_df=month_df.get_group('November')
dec_df=month_df.get_group('December')

# %%
sp_oct_df=oct_df.groupby('Species')
sp_oct_df.Food.get_group('Norovirus genogroup I').dropna()
# Out:
# 1019                                        Multiple Foods
# 1027                                         Seafood Salad
# 1059                        Pasta-Based Salads Unspecified
# 2304                                  Lettuce, Unspecified
# 2305                                         Chicken Salad
# 2310                                              Coleslaw
# 2312                     Potato Salad; Turkey, Unspecified
# 2330               Deli Meat, Multiple; Pre-Packaged Salad
# 2333                                     Cake, Unspecified
# 2337                                     Soda, Unspecified
# 2344     Sandwich, Hoagie; Stew/Chili, Unspecified; Bre...
# 2364                                   Sandwich, Submarine
# 2382                                           House Salad
# 2398                      Lettuce-Based Salads Unspecified
# 2399                                  Chicken, Unspecified
# 3707                                    Onion, Unspecified
# ...

# %%
oct_df.Species.value_counts().max()
# Out:
# 197

# %%
oct_df.groupby
oct_df.Species.value_counts().max().Species
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ba44af74071> in <module>()
# ----> 1 oct_df.groupby
#       2 oct_df.Species.value_counts().max().Species
#
# NameError: name 'oct_df' is not defined

# %%
oct_df.Species.value_counts().max().Species
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-821078ad3a11> in <module>()
# ----> 1 oct_df.Species.value_counts().max().Species
#
# NameError: name 'oct_df' is not defined

# %%
oct_df.Species.value_counts().max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-df0396d72988> in <module>()
# ----> 1 oct_df.Species.value_counts().max()
#
# NameError: name 'oct_df' is not defined
